# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Dataset .csv')

# %% [markdown]
# # TASK 03 PRICE RANGE VS . ONLINE DELIVERY AND TABLE BOOKING
# # ANALYZE IF THERE IS A RELATIONSHIP BETWEEN THE PRICE RANGE AND THE AVAILABILITY OF ONLINE DELIVERY AND TABLE BOOKING.

# %% [raw]
# TO ANALYZED THIS WE NEED TO PLOT 2 CHARTS TOGATHER

# %%
x1=df['Has Online delivery']
y=df['Average Cost for two']
x2=df['Has Table booking']

# %% [raw]
# PLOT 1 FOR ONLINE DELIVERY WITH THE AVG COST
# PLOT 2 FOR TABLE BOOKING WITH THE AVG COST

# %%
plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
sns.boxplot(x=x1,y=y)
plt.xlabel('Online Delivery')
plt.ylabel('Average Cost for two')
plt.title('Online Delivery affected by cost')
plt.subplot(1,2,2)
sns.boxplot(x=x2,y=y)
plt.xlabel('Online Booking')
plt.ylabel('Average Cost for two')
plt.title('Table booking affected by cost')
plt.tight_layout()
plt.show()

# %%
print("Both the Online delivery and Table booking are negetively impacted by the cost")
# Out:
# Both the Online delivery and Table booking are negetively impacted by the cost

# %% [raw]
# DETERMINE IF HIGHER-PRICED RESTAURANTS ARE MORE LIKELY TO OFFER THESE SERVICES.

# %%
print("High riced Restaurants which have average cost more than 10,000 did not provide Online delivery as well as Table Booking facilities.")
# Out:
# High riced Restaurants which have average cost more than 10,000 did not provide Online delivery as well as Table Booking facilities.

# %% [raw]
# let's check for the restaurants have avg cost less than 10,000

# %%
plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
sns.boxplot(x=x1,y='Average Cost for two',data=df.loc[df['Average Cost for two']<10000])
plt.title('Online Delivery by cost')
plt.subplot(1,2,2)
sns.boxplot(x=x2,y='Average Cost for two',data=df.loc[df['Average Cost for two']<10000])
plt.title('Total booking by cost')
plt.tight_layout()
plt.show()

# %%
print("The Online delivery is pesent for only those restaurant , where the avg cost is less than 1000..")
print("The Table booking facility is avalable in restaurants with an avg cost ranging from 10000 to 2000. ")
# Out:
# The Online delivery is pesent for only those restaurant , where the avg cost is less than 1000..
# The Table booking facility is avalable in restaurants with an avg cost ranging from 10000 to 2000.
